# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ![Rightmove Sale Search](../property_scraper/apps/images/rightmove_sale.png)

# %%
from IPython.display import display, HTML

from bs4 import BeautifulSoup
import json
import logging
import pandas as pd
import sys
from tqdm.auto import tqdm

from property_scraper.idealista_scraper import IdealistaScraper
from property_scraper.immobiliare_scraper import ImmobiliareScraper
#from property_scraper.rightmove_scraper import RightmoveScraper

from property_scraper.pvp_scraper import PVPScraper

# %%
API_KEY = 'AIzaSyCT2RdFrh41U-w6_5J6-d_iVxBqV-DWcEs'

search_engine = 'pvp'
#'rightmove' 
#search_engine = 'immobiliare'
#'idealista'
#'pvp'

# %%
logging.basicConfig(level=logging.INFO, stream=sys.stdout, format="%(levelname)s:%(name)s:%(funcName)s:%(message)s")

# %%
if search_engine == 'rightmove':
    scraper = RightmoveScraper('Bristol')
elif search_engine == 'immobiliare':
    scraper = ImmobiliareScraper('Bologna')
elif search_engine == 'idealista':
    scraper = IdealistaScraper('Bologna')
elif search_engine == 'pvp':
    scraper = PVPScraper('Bologna')

# %%
filename = f'../data/{search_engine}.json'
scraper.parameters = scraper.read_parameters(filename)
print(json.dumps(scraper.parameters, indent=4))
# Out:
# {
#     "indirizzo": "ravenna",
#     "paese": "Italia",
#     "vendita_o_affitto": "",
#     "tipo_bene": "immobili",
#     "categoria": "immobile_residenziale",
#     "geo": "raggio",
#     "lat": "",
#     "lng": "",
#     "raggio": 25,
#     "prezzo_da": "",
#     "prezzo_a": "",
#     "tribunale": "",
#     "procedura": "",
#     "anno": "",
#     "idInserzione": "",
#     "ricerca_libera": "",
#     "disponibilita": "",
#     "ordinamento": "data_vendita_cresc",
#     "ordine_localita": "a_z",
#     "view": "tab",
#     "elementiPerPagina": 50
# }

# %%
scraper.url = scraper.set_url(scraper.parameters)
scraper.url
# Out:
# 'https://pvp.giustizia.it/pvp/en/risultati_ricerca.page?indirizzo=ravenna&tipo_bene=immobili&categoria=immobile_residenziale&geo=raggio&raggio=25&ordinamento=data_vendita_cresc&ordine_localita=a_z&view=tab&elementiPerPagina=50'

# %%
#scraper.status_code, scraper.content = scraper.get_request(scraper.url)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/.conda/envs/py310/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...

# %%
scraper.status_code

# %%
scraper.content[:100]

# %%
scraper.number_of_results

# %%
scraper.number_of_pages
# Out:
# 41

# %%
# %%time

scraper.results = scraper.scrape('bs4', 'googlemaps', API_KEY)
# Out:
# INFO:property_scraper.Scraper:scrape:Found 1023 results in 41 pages.
# INFO:property_scraper.Scraper:scrape:Number of branches is : 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 23
#   0%|          | 0/40 [00:00<?, ?it/s]
# INFO:property_scraper.Scraper:get_results:https://www.immobiliare.it/vendita-case/palermo/?criterio=rilevanza&prezzoMinimo=10000&prezzoMassimo=240000&superficieMinima=80&bagni=2&index=25
# INFO:property_scraper.Scraper:get_results:https://www.immobiliare.it/vendita-case/palermo/?criterio=rilevanza&prezzoMinimo=10000&prezzoMassimo=240000&superficieMinima=80&bagni=2&index=50
# INFO:property_scraper.Scraper:get_results:https://www.immobiliare.it/vendita-case/palermo/?criterio=rilevanza&prezzoMinimo=10000&prezzoMassimo=240000&superficieMinima=80&bagni=2&index=75
# ...

# %%
scraper.results.shape
# Out:
# (1000, 46)

# %%
with pd.option_context('display.max_columns', None):
    with pd.option_context('display.max_rows', None):
        with pd.option_context('display.max_colwidth', None):
            display(HTML(scraper.results.head(3).T.to_html().replace("\\n","<br>").replace("\\r","").replace("\\t","")))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>index</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>in-realEstateListCard__content_text</th>
# ...

# %%
urls = sorted(scraper.results['Hyperlink'].unique())
urls[:10]
# Out:
# ['https://www.immobiliare.it/annunci/100058732/',
#  'https://www.immobiliare.it/annunci/100582916/',
#  'https://www.immobiliare.it/annunci/100670209/',
#  'https://www.immobiliare.it/annunci/100675345/',
#  'https://www.immobiliare.it/annunci/101088063/',
#  'https://www.immobiliare.it/annunci/101158975/',
#  'https://www.immobiliare.it/annunci/101202243/',
#  'https://www.immobiliare.it/annunci/101207693/',
#  'https://www.immobiliare.it/annunci/101224605/',
#  'https://www.immobiliare.it/annunci/101268955/']

# %%
soup = BeautifulSoup(scraper.content, 'html.parser')

# %%
scraper.properties = scraper.page.get_properties(urls)
# Out:
#   0%|                                                                                                                                                                                                                | 0/25 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 scraper.properties = scraper.page.get_properties(urls)
#
# File ~/.conda/envs/py310/lib/python3.10/site-packages/property_scraper/page.py:440, in Page.get_properties(self, urls)
#     437     raise ValueError('The request status code is {r.status_code}.')
#     439 soup = BeautifulSoup(r.content, 'html.parser')
# --> 440 _df = self.property.get_data(soup)
#     441 dfs.append(_df)
#     442 sleep_randomly()
#
# AttributeError: 'ImmobiliarePage' object has no attribute 'property'

# %%
with pd.option_context('display.max_columns', None):
    with pd.option_context('display.max_rows', None):
        with pd.option_context('display.max_colwidth', None):
            display(HTML(scraper.properties.head().T.to_html().replace("\\n","<br>").replace("\\r","").replace("\\t","")))

# %%
#list(set(scraper.results['Hyperlink'].unique()))[0]

# %%
#scraper.enrich_results_with_details(scraper.results, 'bs4')

# %%
#results = scraper.enrich_results(scraper.results, 'googlemaps', API_KEY)
#scraper.results.head()

# %%
m = scraper.create_map()
m
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
filename = f'{search_engine}_{scraper.location.lower()}.xlsx'
print(filename)
scraper.results.to_excel(filename, sheet_name=scraper.property_type)

# %%
stop here

# %%
scraper.results['url'].unique()[:10]

# %%
house.url = house.urls[0]
house.url

# %%
#house.url = "https://www.rightmove.co.uk/properties/86492998#/" # house.URL[0]

# %%
house.info

# %%
# %%time

df = house.to_dataframe()
df.head()

# %%
filename = '../output/rightmove_rents_bs.xlsx'
df.to_excel(filename)
