# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # PVP

# %%
from IPython.display import display, HTML

from property_scraper.pvp_scraper import PVPScraper

# %%
url = 'https://pvp.giustizia.it/pvp/it/dettaglio_annuncio.page?contentId=LTT7864288'

# %%
scraper = PVPScraper()

# %%
rent_or_sale = "vendita-case"
no_of_items = 1

# %%
r = requests.get(url)
# Requests to scrape lots of pages eventually get status 400, so:
if r.status_code != 200:
    raise ValueError('The request status code is {r.status_code}.')

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
#data = scraper.page.property.get_data(soup)

# %%
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Reference</th>
#       <th>1878341</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Title</th>
#       <td>Descrizione del compendio immobiliare: Il bene oggetto di pignoramento consta di unità edilizia con destinazione d’uso residenzi...</td>
#     </tr>
#     <tr>
#       <th>Description</th>
#       <td>Descrizione del compendio immobiliare: Il bene oggetto di pignoramento consta di unità edilizia con destinazione d’uso residenziale, attualmente utilizzato come ricovero-casa con relativa porzione di terreno pertinenziale, costruito nel 1973 e ristrutturato parzialmente nel 2007. Il corpo di fabbrica principale è composto dai seguenti vani:<br>- Piano terra: Ingresso, soggiorno-pranzo, locali di servizio quali tavernetta, cantina, 2 bagni e camera di servizio;<br>- Piano primo: disimpegno e vano scale, cinque camere letto, 2 bagni ed una cameretta di servizio; balcone-loggia.</td>
#     </tr>
#     <tr>
#       <th>Link a gestore vendita telematica</th>
#       <td>https://www.astetelematiche.it/vendita-asta-telematica-struttura-assistenziale-ravenna-localita-mandriole-di-ravenna-via-gattolo-superiore-38-scheda=258190?lang=it</td>
#     </tr>
#     <tr>
#       <th>Link per prenotazione della visita dell'immobile</th>
#       <td>https://pvp.giustizia.itprenotazione_visita.page?contentId=LTT7864288&amp;beneId=2316741</td>
#     </tr>
#     <tr>
#       <th>Sito di vendita all'asta</th>
#       <td>https://www.rivistaastegiudiziarie.it/aste/pvp/1878341, https://www.astegiudiziarie.it/vendita-asta-struttura-assistenziale-ravenna-località-mandriole-di-ravenna-via-gattolo-superiore-38-2057851, https://www.canaleaste.it/aste/pvp/1878341, https://www.astalegale.net/Immobili/Detail/B2162788, https://www.asteavvisi.it/aste/pvp/1878341, https://www.asteannunci.it/aste/pvp/1878341, https://www.tribunalediravenna.it/, http://www.asteravenna.eu</td>
#     </tr>
#     <tr>
#       <th>Allegati</th>
#       <td>https://pvp.giustizia.it/pvp-resources/cms/documents/2023/20230215/f4d0582877d88c7abc7867b9253ed3c0.pdf, https://pvp.giustizia.it/pvp-resources/cms/documents/2023/20230215/c1c949b6ad56f7fe50c598c20fb251a8.pdf</td>
#     </tr>
#     <tr>
#       <th>Tipologia del lotto</th>
#       <td>Casa di cura o ospedale</td>
#     </tr>
#     <tr>
#       <th>Dettaglio</th>
#       <td>Immobile attualmente utilizzato come ricovero-casa con relativa porzione di terreno pertinenziale così composto - Piano terra: Ingresso, soggiorno-pranzo, locali di servizio quali tavernetta, cantina, 2 bagni e camera di servizio;<br>- Piano primo: disimpegno e vano scale, cinque camere letto, 2 bagni ed una cameretta di servizio; balcone-loggia.</td>
#     </tr>
#     <tr>
#       <th>Tipologia di vendita</th>
#       <td>Senza incanto</td>
#     </tr>
#     <tr>
#       <th>Data di vendita</th>
#       <td>14/04/2023 09:00</td>
#     </tr>
#     <tr>
#       <th>Prezzo base d'asta</th>
#       <td>€ 207.000,00</td>
#     </tr>
#     <tr>
#       <th>Offerta minima</th>
#       <td>€ 155.250,00</td>
#     </tr>
#     <tr>
#       <th>Rialzo minimo</th>
#       <td>€ 11.000,00</td>
#     </tr>
#     <tr>
#       <th>Modalità di vendita</th>
#       <td>Asincrona telematica</td>
#     </tr>
#     <tr>
#       <th>Termine presentazione offerta</th>
#       <td>13/04/2023 23:59</td>
#     </tr>
#     <tr>
#       <th>Superficie</th>
#       <td>313</td>
#     </tr>
#     <tr>
#       <th>Tipo Procedura</th>
#       <td>ESECUZIONE IMMOBILIARE POST LEGGE 80</td>
#     </tr>
#     <tr>
#       <th>N° Procedura</th>
#       <td>178/2021</td>
#     </tr>
#     <tr>
#       <th>Tribunale</th>
#       <td>Tribunale di RAVENNA</td>
#     </tr>
#     <tr>
#       <th>Lotto nr.</th>
#       <td>LOTTO UNICO</td>
#     </tr>
#     <tr>
#       <th>Pubblicato sul Portale il</th>
#       <td>15/02/2023</td>
#     </tr>
#     <tr>
#       <th>Custode</th>
#       <td>Marco Bigari</td>
#     </tr>
#     <tr>
#       <th>Telefono mobile custode</th>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Telefono custode</th>
#       <td>3934393393</td>
#     </tr>
#     <tr>
#       <th>Email custode</th>
#       <td>segreteria@bibax.net</td>
#     </tr>
#     <tr>
#       <th>Delegato alla vendita</th>
#       <td>Marco Bigari</td>
#     </tr>
#     <tr>
#       <th>Giudice</th>
#       <td>Samuele Labanca</td>
#     </tr>
#   </tbody>
# </table>

# %%
urls = [
    'https://www.immobiliare.it/annunci/100058732/',
    'https://www.immobiliare.it/annunci/100582916/',
    'https://www.immobiliare.it/annunci/100670209/',
    'https://www.immobiliare.it/annunci/100675345/',
    'https://www.immobiliare.it/annunci/101088063/',
    'https://www.immobiliare.it/annunci/101158975/',
    'https://www.immobiliare.it/annunci/101202243/',
    'https://www.immobiliare.it/annunci/101207693/',
    'https://www.immobiliare.it/annunci/101224605/',
    'https://www.immobiliare.it/annunci/101268955/'
]

# %%
data = get_pages(urls)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
with pd.option_context('display.max_columns', None):
    with pd.option_context('display.max_rows', None):
        with pd.option_context('display.max_colwidth', None):
            display(HTML(data.head().T.to_html().replace("\\n","<br>").replace("\\r","").replace("\\t","")))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Reference</th>
#       <th>1878341</th>
#       <th>1878341</th>
#       <th>1878341</th>
#       <th>1878341</th>
#       <th>1878341</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Title</th>
#       <td>Descrizione del compendio immobiliare: Il bene oggetto di pignoramento consta di unità edilizia con destinazione d’uso residenzi...</td>
#       <td>Descrizione del compendio immobiliare: Il bene oggetto di pignoramento consta di unità edilizia con destinazione d’uso residenzi...</td>
#       <td>Descrizione del compendio immobiliare: Il bene oggetto di pignoramento consta di unità edilizia con destinazione d’uso residenzi...</td>
#       <td>Descrizione del compendio immobiliare: Il bene oggetto di pignoramento consta di unità edilizia con destinazione d’uso residenzi...</td>
#       <td>Descrizione del compendio immobiliare: Il bene oggetto di pignoramento consta di unità edilizia con destinazione d’uso residenzi...</td>
#     </tr>
#     <tr>
#       <th>Description</th>
#       <td>Descrizione del compendio immobiliare: Il bene oggetto di pignoramento consta di unità edilizia con destinazione d’uso residenziale, attualmente utilizzato come ricovero-casa con relativa porzione di terreno pertinenziale, costruito nel 1973 e ristrutturato parzialmente nel 2007. Il corpo di fabbrica principale è composto dai seguenti vani:<br>- Piano terra: Ingresso, soggiorno-pranzo, locali di servizio quali tavernetta, cantina, 2 bagni e camera di servizio;<br>- Piano primo: disimpegno e vano scale, cinque camere letto, 2 bagni ed una cameretta di servizio; balcone-loggia.</td>
#       <td>Descrizione del compendio immobiliare: Il bene oggetto di pignoramento consta di unità edilizia con destinazione d’uso resid