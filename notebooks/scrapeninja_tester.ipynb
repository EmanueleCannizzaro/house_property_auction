# %%
import pandas as pd

# %%
filename = '../data/immobiliare_palermo.xlsx'
properties = pd.read_excel(filename, sheet_name='vendita-case')

# %%
print(len(properties))
print(len(properties[properties['Status'] == 'Not available']))
# Out:
# 1022
# 992

# %%
display(properties[properties['Status'] == 'Downloaded'].head(3).T)
# Out:
#                                                                                                 0  \
# Unnamed: 0.2                                                                                    0
# Unnamed: 0.1                                                                                    0
# Unnamed: 0                                                                                      0
# index                                                                                           0
# nd-mediaObject__contentBottom_text                                                Visitamessaggio
# in-photo_text                                                                               20sky
# in-realEstateBadge_text                                                                       sky
# in-realEstateListCard__actions_text                                               Visitamessaggio
# in-card_text                                    20skyQuadrilocale via Tommaso Marcellini 5, Ca...
# in-card_href                                         https://www.immobiliare.it/annunci/99876618/
# nd-mediaObject--colToRow_text                   20skyQuadrilocale via Tommaso Marcellini 5, Ca...
# nd-mediaObject--colToRow_href                        https://www.immobiliare.it/annunci/99876618/
# nd-badge--withText_text                                                                      20.0
# in-realEstateCard_text                          20skyQuadrilocale via Tommaso Marcellini 5, Ca...
# Agent Hyperlink                                      https://www.immobiliare.it/annunci/99876618/
# nd-badge--bottomLeft_text                                                                     sky
# in-photo__media_text                                                                         20.0
# nd-mediaObject__content_text                    Quadrilocale via Tommaso Marcellini 5, Calataf...
# nd-mediaObject__content_href                         https://www.immobiliare.it/annunci/99876618/
# in-card__content_text                           Quadrilocale via Tommaso Marcellini 5, Calataf...
# in-card__content_href                                https://www.immobiliare.it/annunci/99876618/
# in-card__contentBottom_text                                                       Visitamessaggio
# in-realEstateCard--interactive_text             20skyQuadrilocale via Tommaso Marcellini 5, Ca...
# in-realEstateCard--interactive_href                  https://www.immobiliare.it/annunci/99876618/
# in-realEstateListCard__descriptionWrapper_text  Zona Pietratagliata e precisamente in via Tomm...
# in-cardActions_text                                                               Visitamessaggio
# Title                                           Zona Pietratagliata e precisamente in via Tomm...
# in-photo__overlay_text                                                                       20.0
# nd-mediaObject_text                             20skyQuadrilocale via Tommaso Marcellini 5, Ca...
# nd-mediaObject_href                                  https://www.immobiliare.it/annunci/99876618/
# in-realEstateListCard__content_text             Quadrilocale via Tommaso Marcellini 5, Calataf...
# in-realEstateListCard__content_href                  https://www.immobiliare.it/annunci/99876618/
# in-realEstateListCard_text                      20skyQuadrilocale via Tommaso Marcellini 5, Ca...
# in-realEstateListCard_href                           https://www.immobiliare.it/annunci/99876618/
# in-realEstateListCard__mediaContent_text                                                    20sky
# Address                                         Quadrilocale via Tommaso Marcellini 5, Calataf...
# Hyperlink                                            https://www.immobiliare.it/annunci/99876618/
# in-mainFeatures__text_text                                                                     m²
# in-cardActions__button--visit_text                                                         Visita
# in-feat--full_text                                                              € 138.0004115m²21
# in-realEstateListCard__features_text                                            € 138.0004115m²21
# in-feat__mainProperty_text                                                      € 138.0004115m²21
# in-feat_text                                                                    € 138.0004115m²21
# Price                                                                                   € 138.000
# Price Comment                                                                           € 138.000
# in-realEstateResults__item_text                 20skyQuadrilocale via Tommaso Marcellini 5, Ca...
# in-realEstateResults__item_href                      https://www.immobiliare.it/annunci/99876618/
# Search Date                                                            2023-03-06 23:33:50.475000
# in-realEstateListCard__caption_text                                                           NaN
# in-realEstateListCard__descriptionShort_text                                                  NaN
# Geocode                                                                  (38.1019713, 13.3227665)
# color                                                                                         red
# popup                                           ID: Quadrilocale via Tommaso Marcellini 5, Cal...
# Status                                                                                 Downloaded
# Content                                         b'{"info":{"version":"2","statusCode":500,"sta...
#
#                                                                                                 1  \
# Unnamed: 0.2                                                                                    1
# Unnamed: 0.1                                                                                    1
# Unnamed: 0                                                                                      1
# index                                                                                           1
# nd-mediaObject__contentBottom_text                                                Visitamessaggio
# in-photo_text                                                                               44sky
# in-realEstateBadge_text                                                                       sky
# in-realEstateListCard__actions_text                                               Visitamessaggio
# in-card_text                                    44skyAppartamento via Case Spuches 9, Santicel...
# in-card_href                                        https://www.immobiliare.it/annunci/101505517/
# nd-mediaObject--colToRow_text                   44skyAppartamento via Case Spuches 9, Santicel...
# nd-mediaObject--colToRow_href                       https://www.immobiliare.it/annunci/101505517/
# nd-badge--withText_text                                                                      44.0
# in-realEstateCard_text                          44skyAppartamento via Case Spuches 9, Santicel...
# Agent Hyperlink                                     https://www.immobiliare.it/annunci/101505517/
# nd-badge--bottomLeft_text                                                                     sky
# in-photo__media_text                                                                         44.0
# nd-mediaObject__content_text                    Appartamento via Case Spuches 9, Santicelli, P...
# nd-mediaObject__content_href                        https://www.immobiliare.it/annunci/101505517/
# in-card__content_text                           Appartamento via Case Spuches 9, Santicelli, P...
# in-card__content_href                               https://www.immobiliare.it/annunci/101505517/
# in-card__contentBottom_text                                                       Visitamessaggio
# in-realEstateCard--interactive_text             44skyAppartamento via Case Spuches 9, Santicel...
# in-realEstateCard--interactive_href                 https://www.immobiliare.it/annunci/101505517/
# in-realEstateListCard__descriptionWrapper_text  Via Case Spuches, traversa di Via Santicelli, ...
# in-cardActions_text                                                               Visitamessaggio
# Title                                           Via Case Spuches, traversa di Via Santicelli, ...
# in-photo__overlay_text                                                                       44.0
# nd-mediaObject_text                             44skyAppartamento via Case Spuches 9, Santicel...
# nd-mediaObject_href                                 https://www.immobiliare.it/annunci/101505517/
# in-realEstateListCard__content_text             Appartamento via Case Spuches 9, Santicelli, P...
# in-realEstateListCard__content_href                 https://www.immobiliare.it/annunci/101505517/
# in-realEstateListCard_text                      44skyAppartamento via Case Spuches 9, Santicel...
# in-realEstateListCard_href                          https://www.immobiliare.it/annunci/101505517/
# in-realEstateListCard__mediaContent_text                                                    44sky
# Address                                         Appartamento via Case Spuches 9, Santicelli, P...
# Hyperlink                                           https://www.immobiliare.it/annunci/101505517/
# in-mainFeatures__text_text                                                                     m²
# in-cardActions__button--visit_text                                                         Visita
# in-feat--full_text                                                              € 215.0005175m²21
# in-realEstateListCard__features_text                                            € 215.0005175m²21
# in-feat__mainProperty_text                                                      € 215.0005175m²21
# in-feat_text                                                                    € 215.0005175m²21
# Price                                                                                   € 215.000
# Price Comment                                                                           € 215.000
# in-realEstateResults__item_text                 44skyAppartamento via Case Spuches 9, Santicel...
# in-realEstateResults__item_href                     https://www.immobiliare.it/annunci/101505517/
# Search Date                                                            2023-03-06 23:33:50.475000
# in-realEstateListCard__caption_text                                                           NaN
# in-realEstateListCard__descriptionShort_text                                                  NaN
# Geocode                                                                   (38.085127, 13.3058766)
# color                                                                                         red
# popup                                           ID: Appartamento via Case Spuches 9, Santicell...
# Status                                                                                 Downloaded
# Content                                         b'{"info":{"version":"2","statusCode":500,"sta...
#
#                                                                                                 2
# Unnamed: 0.2                                                                                    2
# Unnamed: 0.1                                                                                    2
# Unnamed: 0                                                                                      2
# index                                                                                           2
# nd-mediaObject__contentBottom_text                                                Visitamessaggio
# in-photo_text                                                                               22sky
# in-realEstateBadge_text                                                                       sky
# in-realEstateListCard__actions_text                                               Visitamessaggio
# in-card_text                                    22skyAppartamento largo Francesco Garufi 18, C...
# in-card_href                                         https://www.immobiliare.it/annunci/99875054/
# nd-mediaObject--colToRow_text                   22skyAppartamento largo Francesco Garufi 18, C...
# nd-mediaObject--colToRow_href                        https://www.immobiliare.it/annunci/99875054/
# nd-badge--withText_text                                                                      22.0
# in-realEstateCard_text                          22skyAppartamento largo Francesco Garufi 18, C...
# Agent Hyperlink                                      https://www.immobiliare.it/annunci/99875054/
# nd-badge--bottomLeft_text                                                                     sky
# in-photo__media_text                                                                         22.0
# nd-mediaObject__content_text                    Appartamento largo Francesco Garufi 18, Calata...
# nd-mediaObject__content_href                         https://www.immobiliare.it/annunci/99875054/
# in-card__content_text                           Appartamento largo Francesco Garufi 18, Calata...
# in-card__content_href                                https://www.immobiliare.it/annunci/99875054/
# in-card__contentBottom_text                                                       Visitamessaggio
# in-realEstateCard--interactive_text             22skyAppartamento largo Francesco Garufi 18, C...
# in-realEstateCard--interactive_href                  https://www.immobiliare.it/annunci/99875054/
# in-realEstateListCard__descriptionWrapper_text  Largo Francesco Garufi, in residence su Corso ...
# in-cardActions_text                                                               Visitamessaggio
# Title                                           Largo Francesco Garufi, in residence su Corso ...
# in-photo__overlay_text                                                                       22.0
# nd-mediaObject_text                             22skyAppartamento largo Francesco Garufi 18, C...
# nd-mediaObject_href                                  https://www.immobiliare.it/annunci/99875054/
# in-realEstateListCard__content_text             Appartamento largo Francesco Garufi 18, Calata...
# in-realEstateListCard__content_href                  https://www.immobiliare.it/annunci/99875054/
# in-realEstateListCard_text                      22skyAppartamento largo Francesco Garufi 18, C...
# in-realEstateListCard_href                           https://www.immobiliare.it/annunci/99875054/
# in-realEstateListCard__mediaContent_text                                                    22sky
# Address                                         Appartamento largo Francesco Garufi 18, Calata...
# Hyperlink                                            https://www.immobiliare.it/annunci/99875054/
# in-mainFeatures__text_text                                                                     m²
# in-cardActions__button--visit_text                                                         Visita
# in-feat--full_text                                                              € 235.0005125m²21
# in-realEstateListCard__features_text                                            € 235.0005125m²21
# in-feat__mainProperty_text                                                      € 235.0005125m²21
# in-feat_text                                                                    € 235.0005125m²21
# Price                                                                                   € 235.000
# Price Comment                                                                           € 235.000
# in-realEstateResults__item_text                 22skyAppartamento largo Francesco Garufi 18, C...
# in-realEstateResults__item_href                      https://www.immobiliare.it/annunci/99875054/
# Search Date                                                            2023-03-06 23:33:50.475000
# in-realEstateListCard__caption_text                                                           NaN
# in-realEstateListCard__descriptionShort_text                                                  NaN
# Geocode                                                                  (38.0978745, 13.3166702)
# color                                                                                         red
# popup                                           ID: Appartamento largo Francesco Garufi 18, Ca...
# Status                                                                                 Downloaded
# Content                                         b'{"info":{"version":"2","statusCode":200,"sta...
